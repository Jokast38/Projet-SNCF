# %%
import pymongo
from bson import ObjectId
from pprint import pprint
from dotenv import load_dotenv
import os

# Charger les variables d'environnement depuis le fichier .env
load_dotenv()

# Connexion à MongoDB
MONGO_URI = os.getenv("MONGO_URI")
client = pymongo.MongoClient(MONGO_URI)
db = client["project_cars"]
cars_collection = db["cars"]

# Définir les fonctions pour les requêtes
def get_cars(make=None, model=None, year=None):
    query = {}
    if make:
        query["make"] = {"$regex": make, "$options": "i"}
    if model:
        query["model"] = {"$regex": model, "$options": "i"}
    if year:
        query["year"] = year

    cars = list(cars_collection.find(query))
    return cars

def get_car(car_id):
    car = cars_collection.find_one({"_id": ObjectId(car_id)})
    return car

def delete_car(car_id):
    result = cars_collection.delete_one({"_id": ObjectId(car_id)})
    return {"message": "Voiture supprimée"} if result.deleted_count == 1 else {"message": "Voiture non trouvée"}

def update_car(make, model, year, car_update):
    update_data = {k: v for k, v in car_update.items() if v is not None}
    result = cars_collection.update_one(
        {"make": make, "model": model, "year": year},
        {"$set": update_data}
    )
    if result.modified_count == 1:
        updated_car = cars_collection.find_one({"make": make, "model": model, "year": year})
        return updated_car
    return {"message": "Voiture non trouvée ou non mise à jour"}

def get_total_vehicles():
    total_vehicles = cars_collection.count_documents({})
    return {"total": total_vehicles}

def get_average_power_by_make_model():
    pipeline = [
        {
            "$group": {
                "_id": {"make": "$make", "model": "$model"},
                "average_power": {"$avg": "$power"}
            }
        }
    ]
    result = list(cars_collection.aggregate(pipeline))
    return result

def get_vehicles_by_year():
    pipeline = [
        {
            "$group": {
                "_id": "$year",
                "count": {"$sum": 1}
            }
        }
    ]
    result = list(cars_collection.aggregate(pipeline))
    return result

def get_vehicles_by_make():
    pipeline = [
        {
            "$group": {
                "_id": "$make",
                "count": {"$sum": 1}
            }
        }
    ]
    result = list(cars_collection.aggregate(pipeline))
    return result

def get_vehicles_by_type():
    pipeline = [
        {
            "$group": {
                "_id": "$type",
                "count": {"$sum": 1}
            }
        }
    ]
    result = list(cars_collection.aggregate(pipeline))
    return result

def get_vehicles_by_fuel_type():
    pipeline = [
        {
            "$group": {
                "_id": "$fuel_type",
                "count": {"$sum": 1}
            }
        }
    ]
    result = list(cars_collection.aggregate(pipeline))
    return result

def get_vehicles_by_class():
    pipeline = [
        {
            "$group": {
                "_id": "$car_class",
                "count": {"$sum": 1}
            }
        }
    ]
    result = list(cars_collection.aggregate(pipeline))
    return result

def get_vehicles_by_transmission():
    pipeline = [
        {
            "$group": {
                "_id": "$transmission",
                "count": {"$sum": 1}
            }
        }
    ]
    result = list(cars_collection.aggregate(pipeline))
    return result

def get_average_fuel_economy_by_fuel_type():
    pipeline = [
        {
            "$group": {
                "_id": "$fuel_type",
                "average_city_mpg": {"$avg": "$city_mpg"},
                "average_highway_mpg": {"$avg": "$highway_mpg"},
                "average_combination_mpg": {"$avg": "$combination_mpg"}
            }
        }
    ]
    result = list(cars_collection.aggregate(pipeline))
    return result

def get_average_cylinders_by_make():
    pipeline = [
        {
            "$group": {
                "_id": "$make",
                "average_cylinders": {"$avg": "$cylinders"}
            }
        }
    ]
    result = list(cars_collection.aggregate(pipeline))
    return result

def get_vehicles_by_drive():
    pipeline = [
        {
            "$group": {
                "_id": "$drive",
                "count": {"$sum": 1}
            }
        }
    ]
    result = list(cars_collection.aggregate(pipeline))
    return result

def get_vehicles_by_city_mpg():
    pipeline = [
        {
            "$group": {
                "_id": "$city_mpg",
                "count": {"$sum": 1}
            }
        }
    ]
    result = list(cars_collection.aggregate(pipeline))
    return result

def get_vehicles_by_year_range():
    pipeline = [
        {
            "$bucket": {
                "groupBy": "$year",
                "boundaries": [2000, 2005, 2010, 2015, 2020],
                "default": "Other",
                "output": {
                    "count": {"$sum": 1}
                }
            }
        }
    ]
    result = list(cars_collection.aggregate(pipeline))
    return result

# Afficher les résultats des requêtes
cars = get_cars(make="Toyota")
pprint(cars)

car = get_car("60c72b2f4f1a4e3d2c8e4b8b")
pprint(car)

result = delete_car("60c72b2f4f1a4e3d2c8e4b8b")
pprint(result)

car_update = {"price": 25000}
result = update_car("Toyota", "Camry", 2020, car_update)
pprint(result)

total_vehicles = get_total_vehicles()
pprint(total_vehicles)

average_power = get_average_power_by_make_model()
pprint(average_power)

vehicles_by_year = get_vehicles_by_year()
pprint(vehicles_by_year)

vehicles_by_make = get_vehicles_by_make()
pprint(vehicles_by_make)

vehicles_by_type = get_vehicles_by_type()
pprint(vehicles_by_type)

vehicles_by_fuel_type = get_vehicles_by_fuel_type()
pprint(vehicles_by_fuel_type)

vehicles_by_class = get_vehicles_by_class()
pprint(vehicles_by_class)

vehicles_by_transmission = get_vehicles_by_transmission()
pprint(vehicles_by_transmission)

average_fuel_economy = get_average_fuel_economy_by_fuel_type()
pprint(average_fuel_economy)

average_cylinders = get_average_cylinders_by_make()
pprint(average_cylinders)

vehicles_by_drive = get_vehicles_by_drive()
pprint(vehicles_by_drive)

vehicles_by_city_mpg = get_vehicles_by_city_mpg()
pprint(vehicles_by_city_mpg)

vehicles_by_year_range = get_vehicles_by_year_range()
pprint(vehicles_by_year_range)
# Out:
# [{'_id': ObjectId('67befd617d4d113bf6d2ad66'),
#   'car_class': 'compact car',
#   'city_mpg': 23,
#   'combination_mpg': 24,
#   'cylinders': 4,
#   'displacement': 1.6,
#   'drive': 'fwd',
#   'fuel_type': 'gas',
#   'highway_mpg': 26,
#   'image': '',
#   'make': 'toyota',
#   'model': 'corolla',
#   'power': 2.0,
#   'price': 19999.0,
#   'transmission': 'a',
#   'type': 'compact',
#   'year': 1993},
#  {'_id': ObjectId('67befe38e72348e801c66d5e'),
#   'car_class': 'compact car',
#   'city_mpg': 23,
#   'combination_mpg': 24,
#   'cylinders': 4,
#   'displacement': 1.6,
#   'drive': 'fwd',
#   'fuel_type': 'gas',
#   'highway_mpg': 26,
#   'image': '',
#   'make': 'toyota',
#   'model': 'corolla',
#   'power': 0,
#   'price': 0.0,
#   'transmission': 'a',
#   'year': 1993},
#  {'_id': ObjectId('67c0504dd1d520f9008b5102'),
#   'city_mpg': 22,
#   'class': 'midsize car',
#   'combination_mpg': 26,
#   'cylinders': 6,
#   'displacement': 3.5,
#   'drive': 'fwd',
#   'fuel_type': 'gas',
#   'highway_mpg': 33,
#   'make': 'toyota',
#   'model': 'camry',
#   'power': 0,
#   'price': 0,
#   'transmission': 'a',
#   'year': 2021},
#  {'_id': ObjectId('67c0504ed1d520f9008b5103'),
#   'city_mpg': 22,
#   'class': 'midsize car',
#   'combination_mpg': 26,
#   'cylinders': 6,
#   'displacement': 3.5,
#   'drive': 'fwd',
#   'fuel_type': 'gas',
#   'highway_mpg': 33,
#   'make': 'toyota',
#   'model': 'camry',
#   'power': 0,
#   'price': 0,
#   'transmission': 'a',
#   'year': 2022},
#  {'_id': ObjectId('67c0527e53375954889a05eb'),
#   'city_mpg': 22,
#   'class': 'midsize car',
#   'combination_mpg': 26,
#   'cylinders': 6,
#   'displacement': 3.5,
#   'drive': 'fwd',
#   'fuel_type': 'gas',
#   'highway_mpg': 33,
#   'make': 'toyota',
#   'model': 'camry',
#   'power': 0,
#   'price': 0.0,
#   'transmission': 'a',
#   'year': 2020},
#  {'_id': ObjectId('67c0528053375954889a05ec'),
#   'city_mpg': 22,
#   'class': 'midsize car',
#   'combination_mpg': 26,
#   'cylinders': 6,
#   'displacement': 3.5,
#   'drive': 'fwd',
#   'fuel_type': 'gas',
#   'highway_mpg': 33,
#   'make': 'toyota',
#   'model': 'camry',
#   'power': 0,
#   'price': 0.0,
#   'transmission': 'a',
#   'year': 2021},
#  {'_id': ObjectId('67c0528153375954889a05ed'),
#   'city_mpg': 22,
#   'class': 'midsize car',
#   'combination_mpg': 26,
#   'cylinders': 6,
#   'displacement': 3.5,
#   'drive': 'fwd',
#   'fuel_type': 'gas',
#   'highway_mpg': 33,
#   'make': 'toyota',
#   'model': 'camry',
#   'power': 0,
#   'price': 0.0,
#   'transmission': 'a',
#   'year': 2022},
#  {'_id': ObjectId('67c06be155464a002b53b05c'),
#   'city_mpg': 22,
#   'class': 'midsize car',
#   'combination_mpg': 26,
#   'cylinders': 6,
#   'displacement': 3.5,
#   'drive': 'fwd',
#   'fuel_type': 'gas',
#   'highway_mpg': 33,
#   'make': 'Toyota',
#   'model': 'Camry',
#   'power': 0.0,
#   'price': 0.0,
#   'transmission': 'a',
#   'type': 'Unknown',
#   'year': 2020},
#  {'_id': ObjectId('67c06be355464a002b53b05d'),
#   'city_mpg': 22,
#   'class': 'midsize car',
#   'combination_mpg': 26,
#   'cylinders': 6,
#   'displacement': 3.5,
#   'drive': 'fwd',
#   'fuel_type': 'gas',
#   'highway_mpg': 33,
#   'make': 'Toyota',
#   'model': 'Camry',
#   'power': 0.0,
#   'price': 0.0,
#   'transmission': 'a',
#   'type': 'Unknown',
#   'year': 2021},
#  {'_id': ObjectId('67c06be555464a002b53b05e'),
#   'city_mpg': 22,
#   'class': 'midsize car',
#   'combination_mpg': 26,
#   'cylinders': 6,
#   'displacement': 3.5,
#   'drive': 'fwd',
#   'fuel_type': 'gas',
#   'highway_mpg': 33,
#   'make': 'Toyota',
#   'model': 'Camry',
#   'power': 0.0,
#   'price': 0.0,
#   'transmission': 'a',
#   'type': 'Unknown',
#   'year': 2022},
#  {'_id': ObjectId('67c06be655464a002b53b05f'),
#   'city_mpg': 22,
#   'class': 'midsize car',
#   'combination_mpg': 26,
#   'cylinders': 6,
#   'displacement': 3.5,
#   'drive': 'fwd',
#   'fuel_type': 'gas',
#   'highway_mpg': 33,
#   'make': 'Toyota',
#   'model': 'Camry',
#   'power': 0.0,
#   'price': 0.0,
#   'transmission': 'a',
#   'type': 'Unknown',
#   'year': 2023}]
# None
# {'message': 'Voiture non trouvée'}
# {'_id': ObjectId('67c06be155464a002b53b05c'),
#  'city_mpg': 22,
#  'class': 'midsize car',
#  'combination_mpg': 26,
#  'cylinders': 6,
#  'displacement': 3.5,
#  'drive': 'fwd',
#  'fuel_type': 'gas',
#  'highway_mpg': 33,
#  'make': 'Toyota',
#  'model': 'Camry',
#  'power': 0.0,
#  'price': 25000,
#  'transmission': 'a',
#  'type': 'Unknown',
#  'year': 2020}
# {'total': 69}
# [{'_id': {'make': 'audi', 'model': 'a5 coupe quattro'}, 'average_power': 0.0},
#  {'_id': {'make': 'nissan', 'model': 'altima'}, 'average_power': 0.0},
#  {'_id': {'make': 'honda', 'model': 'civic 5dr'}, 'average_power': 0.0},
#  {'_id': {'make': 'Chevrolet', 'model': 'Silverado'}, 'average_power': 0.0},
#  {'_id': {'make': 'lamborghini', 'model': 'urus performante'},
#   'average_power': 0.0},
#  {'_id': {'make': 'Mercedes-benz', 'model': 'GLC'}, 'average_power': 0.0},
#  {'_id': {'make': 'Ford', 'model': 'F-150'}, 'average_power': 0.0},
#  {'_id': {'make': 'ford', 'model': 'taurus'}, 'average_power': 0.0},
#  {'_id': {'make': 'Honda', 'model': 'Civic'}, 'average_power': 0.0},
#  {'_id': {'make': 'toyota', 'model': 'camry'}, 'average_power': 0.0},
#  {'_id': {'make': 'Nissan', 'model': 'Altima'}, 'average_power': 0.0},
#  {'_id': {'make': 'Mercedes-benz', 'model': 'C63 AMG'}, 'average_power': 1.0},
#  {'_id': {'make': 'ford', 'model': 'f-150 lightning platinum 4wd'},
#   'average_power': 0.0},
#  {'_id': {'make': 'Audi', 'model': 'A4'}, 'average_power': 0.0},
#  {'_id': {'make': 'Volkswagen', 'model': 'Golf'}, 'average_power': 0.0},
#  {'_id': {'make': 'Hyundai', 'model': 'Elantra'}, 'average_power': 0.0},
#  {'_id': {'make': 'Mercedes', 'model': 'c63 amg'}, 'average_power': 5.0},
#  {'_id': {'make': 'lamborghini', 'model': 'huracan spyder'},
#   'average_power': None},
#  {'_id': {'make': 'honda', 'model': 'civic 4dr'}, 'average_power': 0.0},
#  {'_id': {'make': 'toyota', 'model': 'corolla'}, 'average_power': 1.0},
#  {'_id': {'make': 'Toyota', 'model': 'Camry'}, 'average_power': 0.0},
#  {'_id': {'make': 'chevrolet', 'model': 'silverado 2wd'}, 'average_power': 0.0},
#  {'_id': {'make': 'ford', 'model': 'mustang'}, 'average_power': 0.0}]
# [{'_id': 2021, 'count': 16},
#  {'_id': 1993, 'count': 4},
#  {'_id': 2022, 'count': 21},
#  {'_id': 2002, 'count': 1},
#  {'_id': 2020, 'count': 17},
#  {'_id': 2023, 'count': 10}]
# [{'_id': 'honda', 'count': 6},
#  {'_id': 'toyota', 'count': 7},
#  {'_id': 'Honda', 'count': 4},
#  {'_id': 'Mercedes-benz', 'count': 3},
#  {'_id': 'nissan', 'count': 8},
#  {'_id': 'Mercedes', 'count': 1},
#  {'_id': 'Volkswagen', 'count': 4},
#  {'_id': 'lamborghini', 'count': 2},
#  {'_id': 'Chevrolet', 'count': 4},
#  {'_id': 'Toyota', 'count': 4},
#  {'_id': 'Nissan', 'count': 4},
#  {'_id': 'Ford', 'count': 2},
#  {'_id': 'Hyundai', 'count': 4},
#  {'_id': 'Audi', 'count': 4},
#  {'_id': 'audi', 'count': 1},
#  {'_id': 'ford', 'count': 5},
#  {'_id': 'chevrolet', 'count': 6}]
# [{'_id': 'Unknown', 'count': 31},
#  {'_id': 'compact', 'count': 1},
#  {'_id': 'Type 253', 'count': 1},
#  {'_id': None, 'count': 34},
#  {'_id': 'berline', 'count': 2}]
# [{'_id': 'electricity', 'count': 4},
#  {'_id': 'diesel', 'count': 3},
#  {'_id': 'gas', 'count': 62}]
# [{'_id': 'midsize car', 'count': 4},
#  {'_id': 'compact car', 'count': 2},
#  {'_id': 'small station wagon', 'count': 1},
#  {'_id': 'subcompact car', 'count': 2},
#  {'_id': None, 'count': 59},
#  {'_id': 'two seater', 'count': 1}]
# [{'_id': 'a', 'count': 62}, {'_id': 'm', 'count': 7}]
# [{'_id': 'diesel',
#   'average_city_mpg': 23.0,
#   'average_combination_mpg': 26.0,
#   'average_highway_mpg': 31.0},
#  {'_id': 'gas',
#   'average_city_mpg': 24.225806451612904,
#   'average_combination_mpg': 27.387096774193548,
#   'average_highway_mpg': 32.854838709677416},
#  {'_id': 'electricity',
#   'average_city_mpg': 74.25,
#   'average_combination_mpg': 67.0,
#   'average_highway_mpg': 60.75}]
# [{'_id': 'Mercedes', 'average_cylinders': 4.0},
#  {'_id': 'nissan', 'average_cylinders': 4.0},
#  {'_id': 'toyota', 'average_cylinders': 5.428571428571429},
#  {'_id': 'Honda', 'average_cylinders': 4.0},
#  {'_id': 'honda', 'average_cylinders': 4.0},
#  {'_id': 'Mercedes-benz', 'average_cylinders': 4.0},
#  {'_id': 'Toyota', 'average_cylinders': 6.0},
#  {'_id': 'Chevrolet', 'average_cylinders': 7.0},
#  {'_id': 'Volkswagen', 'average_cylinders': 4.0},
#  {'_id': 'lamborghini', 'average_cylinders': 9.0},
#  {'_id': 'Audi', 'average_cylinders': 4.0},
#  {'_id': 'Ford', 'average_cylinders': None},
#  {'_id': 'Hyundai', 'average_cylinders': 4.0},
#  {'_id': 'Nissan', 'average_cylinders': 4.0},
#  {'_id': 'chevrolet', 'average_cylinders': 6.666666666666667},
#  {'_id': 'audi', 'average_cylinders': 4.0},
#  {'_id': 'ford', 'average_cylinders': 3.6}]
# [{'_id': '4wd', 'count': 2},
#  {'_id': 'rwd', 'count': 11},
#  {'_id': 'fwd', 'count': 42},
#  {'_id': 'awd', 'count': 14}]
# [{'_id': 33, 'count': 4},
#  {'_id': 15, 'count': 3},
#  {'_id': 24, 'count': 3},
#  {'_id': 29, 'count': 8},
#  {'_id': 16, 'count': 4},
#  {'_id': 18, 'count': 2},
#  {'_id': 20, 'count': 5},
#  {'_id': 13, 'count': 1},
#  {'_id': 22, 'count': 9},
#  {'_id': 73, 'count': 3},
#  {'_id': 17, 'count': 1},
#  {'_id': 23, 'count': 6},
#  {'_id': 14, 'count': 1},
#  {'_id': 26, 'count': 1},
#  {'_id': 78, 'count': 1},
#  {'_id': 30, 'count': 2},
#  {'_id': 28, 'count': 11},
#  {'_id': 31, 'count': 2},
#  {'_id': 27, 'count': 2}]
# [{'_id': 2000, 'count': 1}, {'_id': 'Other', 'count': 68}]
